# %%
from astropy.table import Table, vstack
import numpy as np
import matplotlib.pyplot as plt
import fitsio

# %%
elgtab = Table(fitsio.read("/global/cfs/cdirs/desi/public/edr/vac/edr/uchuu/v1.0/ELG_Uchuu/ELG_N_0_uchuu.dat.fits"))

# %%
elgtab
# Out:
# <Table length=101786>
#         RA                DEC         ...      WEIGHT_FKP
#      float64            float64       ...       float64
# ------------------ ------------------ ... -------------------
#   217.222486984756  52.83891617559396 ...  0.1889167129444393
# 216.60622478619828  53.13531870459978 ... 0.18823997133959156
#  218.2361044681571  52.83479957534304 ... 0.18544916860765553
# 216.19049795035767  52.87362328324661 ... 0.18747626492956732
#   215.907740781944 52.998672711786526 ... 0.18900516566391706
# 214.30996524676553  52.28294309488814 ...  0.1878628802015117
#  215.8973177809078 52.904593624761624 ... 0.18470807504646064
# 217.19854463576618  53.81770411006356 ...   0.186364386207936
#  216.5167093167063   52.4202211983118 ... 0.18754232489387282
#                ...                ... ...                 ...
# 237.17193556705863  43.11563048132602 ... 0.35001218263327427
# 244.52409724167316  44.33606581142436 ...  0.3506373234529035
# ...
