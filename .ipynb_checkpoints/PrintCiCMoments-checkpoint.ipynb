# %%
from CiCMoments import *
from CountsinCylinders import *
import matplotlib

#set up auto-reload for development purposes

# %load_ext autoreload
# %autoreload 2

# %%
def plotMomentRatio(ratio,saveas='forpaper/momentratio.png',elg=True):
    matplotlib.fontsize = 25
    data = np.ones((4,4))
    for i in range(4):
        for j in range(4):
            if i + j > 3:
                data[i][j] = None
    data
    for row in ratio:
        data[int(row['ELG Order, LRG Order'][0])][int(row['ELG Order, LRG Order'][1])] = row['Moment']
    fig,ax = plt.subplots()
    pc = ax.pcolormesh(np.arange(4),np.arange(4),data,cmap='RdBu',vmin=0.7,vmax=1.3)
    ax.set_xlabel("ELG Order",fontsize=20,labelpad=20)
    ax.set_ylabel("LRG Order",fontsize=20,labelpad=20)
    ax.tick_params(axis='both', which='major', labelsize=20)
    ax.set_xticks([0,1,2,3],labelsize=50)
    ax.set_yticks([0,1,2,3])
    ax.tick_params(axis='both', which='both', length=0)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.spines['bottom'].set_visible(False)
    ax.spines['left'].set_visible(False)
    cbar = plt.colorbar(pc)
    for i in range(4):
        for j in range(4):
    plt.savefig(saveas)

# %%
ab_elg_momsimple = Table.read("ab_elg_momsimple.ecsv")
ab_lrg_momsimple = Table.read("ab_lrg_momsimple.ecsv")


sv3_elg_momsimple = Table.read("sv3_elg_momsimple.ecsv") #,savesubsamples=True)
sv3_lrg_momsimple = Table.read("sv3_lrg_momsimple.ecsv") #,savesubsamples=True)

# %%
compelg_simple = momentRatio(ab_elg_momsimple,sv3_elg_momsimple)
complrg_simple = momentRatio(ab_lrg_momsimple,sv3_lrg_momsimple)

# %%
compelg_simple[0]['ELG Order, LRG Order'][0]
# Out:
# 0

# %%
plotMomentRatio(compelg_simple,saveas="forpaper/elgmomentratio.png")

# %%
ab_elg_momfactorial = Table.read('ab_elg_momfactorial.ecsv')
ab_lrg_momfactorial = Table.read('ab_lrg_momfactorial.ecsv')


sv3_elg_momfactorial = Table.read('sv3_elg_momfactorial.ecsv')
sv3_lrg_momfactorial = Table.read('sv3_lrg_momfactorial.ecsv')

# %%
compelg_factorial = momentRatio(ab_elg_momfactorial,sv3_elg_momfactorial)
complrg_factorial = momentRatio(ab_lrg_momfactorial,sv3_lrg_momfactorial)

# %%
ab_elg_ntilde = Table.read('ab_elg_ntilde.escv',format = 'ascii.ecsv')
ab_lrg_ntilde = Table.read('ab_lrg_ntilde.escv',format = 'ascii.ecsv')
sv3_elg_ntilde = Table.read('sv3_elg_ntilde.escv',format = 'ascii.ecsv')
sv3_lrg_ntilde = Table.read('sv3_lrg_ntilde.escv',format = 'ascii.ecsv')

compelg_ntilde = momentRatio(ab_elg_ntilde,sv3_elg_ntilde)
complrg_ntilde = momentRatio(ab_lrg_ntilde,sv3_lrg_ntilde)

# %%
abran_elg_momsimple = Table.read(filename='abran_elg_momsimple.escv',format = 'ascii.ecsv')
abran_lrg_momsimple = Table.read('abran_lrg_momsimple.escv',format = 'ascii.ecsv')

#extraargs = [Vcyl,sv3_elg_nZ,sv3_lrg_nZ]
sv3ran_elg_momsimple = Table.read('sv3ran_elg_momsimple.ecsv',format = 'ascii.ecsv')
sv3ran_lrg_momsimple = Table.read('sv3ran_lrg_momsimple.ecsv',format = 'ascii.ecsv')

# %%
abran_elg_ntilde = Table.read('abran_elg_ntilde.escv',format = 'ascii.ecsv')
abran_lrg_ntilde = Table.read('abran_lrg_ntilde.escv',format = 'ascii.ecsv')

sv3ran_elg_ntilde = Table.read('sv3ran_elg_ntilde.ecsv',format = 'ascii.ecsv')
sv3ran_lrg_ntilde = Table.read('sv3ran_lrg_ntilde.ecsv',format = 'ascii.ecsv')

# %%
ab_elg_nz = Table.read("ab_elg_nz.ecsv")
ab_lrg_nz = Table.read("ab_lrg_nz.ecsv")

sv3_elg_nz = Table.read("sv3_elg_nz.ecsv")
sv3_lrg_nz = Table.read("sv3_lrg_nz.ecsv")

# %%
ab_elg_vcyl = Table.read("ab_elg_vcyl.ecsv")
ab_lrg_vcyl = Table.read("ab_lrg_vcyl.ecsv")

sv3_elg_vcyl = Table.read("sv3_elg_vcyl.ecsv")
sv3_lrg_vcyl = Table.read("sv3_lrg_vcyl.ecsv")

# %%
sv3_elg_npcf = avgnpcf(sv3_elg_ntilde,sv3ran_elg_ntilde,sv3_elg_nz,sv3_elg_vcyl)
sv3_lrg_npcf = avgnpcf(sv3_lrg_ntilde,sv3ran_lrg_ntilde,sv3_lrg_nz,sv3_lrg_vcyl)

ab_elg_npcf = avgnpcf(ab_elg_ntilde,abran_elg_ntilde,ab_elg_nz,ab_elg_vcyl)
ab_lrg_npcf = avgnpcf(ab_lrg_ntilde,abran_lrg_ntilde,ab_lrg_nz,ab_elg_vcyl)

# %%
compelg_npcf = momentRatio(ab_elg_npcf,sv3_elg_npcf)
complrg_npcf = momentRatio(ab_lrg_npcf,sv3_lrg_npcf)

# %%
string1 = printMomentTableLaTeX(compelg_simple,"Moments of ELG-Centered Counts in Cylinders Distribution: Ratio of Abacus to SV3",lrg=False)
print(string1)
string1 = printMomentTableLaTeX(complrg_simple,"Moments of LRG-Centered Counts in Cylinders Distribution: Ratio of Abacus to SV3",lrg=True)
print(string1)

string1 = printMomentTableLaTeX(sv3_elg_momsimple,"Moments of ELG-Centered Counts in Cylinders Distribution in SV3",lrg=False)
print(string1)
string1 = printMomentTableLaTeX(sv3_lrg_momsimple,"Moments of LRG-Centered Counts in Cylinders Distribution in SV3",lrg=True)
print(string1)
# Out:
#     \begin{table}
#     \caption{Moments of ELG-Centered Counts in Cylinders Distribution: Ratio of Abacus to SV3}
#     \begin{tabular}{ c  c  c  c c c}
#     \multicolumn{2}{c}{}&\multicolumn{4}{c}{LRG Order}\\
#      \multicolumn{1}{c}{}& &  0&1&  2 &3\\ \cline{2-6}
#
#     \multirow[|l|]{4}{*}{\rotatebox[origin=c]{90}{ELG Order}}& \multicolumn{1}{c|}{0} && 0.981
#  ( 0.0395 ) & 0.963
#  ( 0.0479 )&0.929
#  ( 0.0723 )\\
#      & \multicolumn{1}{c|}{1} &1.11
#  ( 0.0208 )&1.13
#  ( 0.0994 )&1.14
#  ( 0.109 )&\multicolumn{1}{c}{}\\
#
#      &\multicolumn{1}{c|}{2} & 1.1
#  ( 0.0286 )&1.13
#  ( 0.119 )& \multicolumn{2}{c}{}\\
#      &\multicolumn{1}{c|}{3} &1.07
#  ( 0.0653 )& \multicolumn{2}{c}{}\\
#
#     \end{tabular}
#
#     \end{table}
#
#     \begin{table}
#     \caption{Moments of LRG-Centered Counts in Cylinders Distribution: Ratio of Abacus to SV3}
#     \begin{tabular}{ c  c  c  c c c}
#     \multicolumn{2}{c}{}&\multicolumn{4}{c}{ELG Order}\\
#      \multicolumn{1}{c}{}& &  0&1&  2 &3\\ \cline{2-6}
#
#     \multirow[|l|]{4}{*}{\rotatebox[origin=c]{90}{LRG Order}}& \multicolumn{1}{c|}{0} && 0.961
#  ( 0.0393 ) & 0.958
#  ( 0.0492 )&0.941
#  ( 0.0694 )\\
#      & \multicolumn{1}{c|}{1} &0.994
#  ( 0.0386 )&0.928
#  ( 0.0808 )&0.954
#  ( 0.0912 )&\multicolumn{1}{c}{}\\
#
#      &\multicolumn{1}{c|}{2} & 0.876
#  ( 0.0664 )&0.875
#  ( 0.11 )& \multicolumn{2}{c}{}\\
#      &\multicolumn{1}{c|}{3} &0.778
#  ( 0.105 )& \multicolumn{2}{c}{}\\
#
#     \end{tabular}
#
#     \end{table}
#
#     \begin{table}
#     \caption{Moments of ELG-Centered Counts in Cylinders Distribution in SV3}
#     \begin{tabular}{ c  c  c  c c c}
#     \multicolumn{2}{c}{}&\multicolumn{4}{c}{LRG Order}\\
#      \multicolumn{1}{c}{}& &  0&1&  2 &3\\ \cline{2-6}
#
#     \multirow[|l|]{4}{*}{\rotatebox[origin=c]{90}{ELG Order}}& \multicolumn{1}{c|}{0} && 0.054
#  ( 0.00213 ) & 0.0708
#  ( 0.00338 )&0.116
#  ( 0.00837 )\\
#      & \multicolumn{1}{c|}{1} &0.0936
#  ( 0.00193 )&0.00793
#  ( 0.000785 )&0.0106
#  ( 0.00115 )&\multicolumn{1}{c}{}\\
#
#      &\multicolumn{1}{c|}{2} & 0.109
#  ( 0.00308 )&0.00962
#  ( 0.00114 )& \multicolumn{2}{c}{}\\
#      &\multicolumn{1}{c|}{3} &0.143
#  ( 0.00927 )& \multicolumn{2}{c}{}\\
#
#     \end{tabular}
#
#     \end{table}
#
#     \begin{table}
#     \caption{Moments of LRG-Centered Counts in Cylinders Distribution in SV3}
#     \begin{tabular}{ c  c  c  c c c}
#     \multicolumn{2}{c}{}&\multicolumn{4}{c}{ELG Order}\\
#      \multicolumn{1}{c}{}& &  0&1&  2 &3\\ \cline{2-6}
#
#     \multirow[|l|]{4}{*}{\rotatebox[origin=c]{90}{LRG Order}}& \multicolumn{1}{c|}{0} && 0.102
#  ( 0.00401 ) & 0.119
#  ( 0.00587 )&0.16
#  ( 0.0111 )\\
#      & \multicolumn{1}{c|}{1} &0.261
#  ( 0.01 )&0.0353
#  ( 0.00285 )&0.0415
#  ( 0.00377 )&\multicolumn{1}{c}{}\\
#
#      &\multicolumn{1}{c|}{2} & 0.475
#  ( 0.0314 )&0.0643
#  ( 0.00706 )& \multicolumn{2}{c}{}\\
#      &\multicolumn{1}{c|}{3} &1.18
#  ( 0.123 )& \multicolumn{2}{c}{}\\
#
#     \end{tabular}
#
#     \end{table}

# %%
'''string1 = printMomentTableLaTeX(compelg_ntilde,r"$\tilde{N}$ in ELG-Centered Counts in Cylinders Distribution: Ratio of Abacus to SV3",lrg=False)
print(string1)
string1 = printMomentTableLaTeX(complrg_ntilde,r"$\tilde{N}$ LRG-Centered Counts in Cylinders Distribution: Ratio of Abacus to SV3",lrg=True)
print(string1)''''
# Out:
#     \begin{table}
#     \caption{$\tilde{N}$ in ELG-Centered Counts in Cylinders Distribution: Ratio of Abacus to SV3}
#     \begin{tabular}{ |c  |c  |c  |c|c |c|}
#     \cline{3-6}
#     \multicolumn{2}{c}{}&\multicolumn{4}{|c|}{LRG Order}\\\cline{3-6}
#      \multicolumn{1}{c}{}& &  0&1&  2 &3\\[2pt] \hline
#
#     \multirow[|l|]{4}{*}{\rotatebox[origin=c]{90}{ELG Order}}& \multicolumn{1}{|c|}{0} && 0.968
#  $\pm$ 0.045 & 0.839
#  $\pm$ 0.088&0.768
#  $\pm$ 0.172\\[2pt]\cline{2-6}
#      & \multicolumn{1}{|c|}{1} &1.139
#  $\pm$ 0.028&1.191
#  $\pm$ 0.126&1.256
#  $\pm$ 0.284&\multicolumn{1}{|c}{}\\[2pt]
#     \cline{2-5}
#      &\multicolumn{1}{|c|}{2} & 1.007
#  $\pm$ 0.189&1.390
#  $\pm$ 0.387& \multicolumn{2}{|c}{}\\[2pt] \cline{2-4}
#      &\multicolumn{1}{|c|}{3} &0.590
#  $\pm$ 0.938& \multicolumn{2}{|c}{}\\[2pt] \cline{1-3}
#
#     \end{tabular}
#
#     \end{table}
#
#     \begin{table}
#     \caption{$\tilde{N}$ LRG-Centered Counts in Cylinders Distribution: Ratio of Abacus to SV3}
#     \begin{tabular}{ |c  |c  |c  |c|c |c|}
#     \cline{3-6}
#     \multicolumn{2}{c}{}&\multicolumn{4}{|c|}{ELG Order}\\\cline{3-6}
#      \multicolumn{1}{c}{}& &  0&1&  2 &3\\[2pt] \hline
#
#     \multirow[|l|]{4}{*}{\rotatebox[origin=c]{90}{LRG Order}}& \multicolumn{1}{|c|}{0} && 0.928
#  $\pm$ 0.049 & 0.940
#  $\pm$ 0.143&0.608
#  $\pm$ 0.379\\[2pt]\cline{2-6}
#      & \multicolumn{1}{|c|}{1} &1.001
#  $\pm$ 0.034&0.845
#  $\pm$ 0.100&1.134
#  $\pm$ 0.291&\multicolumn{1}{|c}{}\\[2pt]
#     \cline{2-5}
#      &\multicolumn{1}{|c|}{2} & 0.795
#  $\pm$ 0.088&0.763
#  $\pm$ 0.158& \multicolumn{2}{|c}{}\\[2pt] \cline{2-4}
#      &\multicolumn{1}{|c|}{3} &0.812
#  $\pm$ 0.151& \multicolumn{2}{|c}{}\\[2pt] \cline{1-3}
#
#     \end{tabular}
#
#     \end{table}

# %%
string1 = printMomentTableLaTeX(sv3_elg_npcf,r"ELG-Centered $\bar{\xi}_{\text{cyl}}$ in SV3",lrg=False,scientific=True)
print(string1)
string1 = printMomentTableLaTeX(ab_elg_npcf,r"ELG-Centered $\bar{\xi}_{\text{cyl}}$ in Abacus",lrg=False,scientific=True)
print(string1)
string1 = printMomentTableLaTeX(sv3_lrg_npcf,r"LRG-Centered $\bar{\xi}_{\text{cyl}}$ in SV3",lrg=True,scientific=True)
print(string1)
string1 = printMomentTableLaTeX(ab_lrg_npcf,r"LRG-Centered $\bar{\xi}_{\text{cyl}}$ in Abacus",lrg=True,scientific=True)
print(string1)
# Out:
#     \begin{table}
#     \caption{ELG-Centered $\bar{\xi}_{\text{cyl}}$ in SV3}
#     \begin{tabular}{ c  c  c  c c c}
#     \multicolumn{2}{c}{}&\multicolumn{4}{c}{LRG Order}\\
#      \multicolumn{1}{c}{}& &  0&1&  2 &3\\ \cline{3-6}
#
#     \multirow[|l|]{4}{*}{\rotatebox[origin=c]{90}{ELG Order}}& \multicolumn{1}{c|}{0} && 2.92
#  ( 0.138 ) & 69.4
#  ( 7.24 )&3.18e+03
#  ( 640 )\\
#      & \multicolumn{1}{c|}{1} &2.36
#  ( 0.0672 )&11.7
#  ( 1.75 )&318
#  ( 100 )&\multicolumn{1}{c}{}\\
#
#      &\multicolumn{1}{c|}{2} & 10.7
#  ( 2.36 )&79.9
#  ( 33.9 )& \multicolumn{2}{c}{}\\
#      &\multicolumn{1}{c|}{3} &129
#  ( 125 )& \multicolumn{2}{c}{}\\
#
#     \end{tabular}
#
#     \end{table}
#
#     \begin{table}
#     \caption{ELG-Centered $\bar{\xi}_{\text{cyl}}$ in Abacus}
#     \begin{tabular}{ c  c  c  c c c}
#     \multicolumn{2}{c}{}&\multicolumn{4}{c}{LRG Order}\\
#      \multicolumn{1}{c}{}& &  0&1&  2 &3\\ \cline{3-6}
#
#     \multirow[|l|]{4}{*}{\rotatebox[origin=c]{90}{ELG Order}}& \multicolumn{1}{c|}{0} && 2.79
#  ( 0.0125 ) & 56.4
#  ( 0.644 )&2.46e+03
#  ( 90.4 )\\
#      & \multicolumn{1}{c|}{1} &2.62
#  ( 0.00988 )&14
#  ( 0.155 )&393
#  ( 14.4 )&\multicolumn{1}{c}{}\\
#
#      &\multicolumn{1}{c|}{2} & 9.79
#  ( 0.214 )&106
#  ( 5.96 )& \multicolumn{2}{c}{}\\
#      &\multicolumn{1}{c|}{3} &66.3
#  ( 7.3 )& \multicolumn{2}{c}{}\\
#
#     \end{tabular}
#
#     \end{table}
#
#     \begin{table}
#     \caption{LRG-Centered $\bar{\xi}_{\text{cyl}}$ in SV3}
#     \begin{tabular}{ c  c  c  c c c}
#     \multicolumn{2}{c}{}&\multicolumn{4}{c}{ELG Order}\\
#      \multicolumn{1}{c}{}& &  0&1&  2 &3\\ \cline{3-6}
#
#     \multirow[|l|]{4}{*}{\rotatebox[origin=c]{90}{LRG Order}}& \multicolumn{1}{c|}{0} && 2.61
#  ( 0.126 ) & 12.8
#  ( 2.1 )&147
#  ( 58.8 )\\
#      & \multicolumn{1}{c|}{1} &16.7
#  ( 0.565 )&64.5
#  ( 6.63 )&351
#  ( 104 )&\multicolumn{1}{c}{}\\
#
#      &\multicolumn{1}{c|}{2} & 816
#  ( 72.5 )&3.48e+03
#  ( 548 )& \multicolumn{2}{c}{}\\
#      &\multicolumn{1}{c|}{3} &5.85e+04
#  ( 8.79e+03 )& \multicolumn{2}{c}{}\\
#
#     \end{tabular}
#
#     \end{table}
#
#     \begin{table}
#     \caption{LRG-Centered $\bar{\xi}_{\text{cyl}}$ in Abacus}
#     \begin{tabular}{ c  c  c  c c c}
#     \multicolumn{2}{c}{}&\multicolumn{4}{c}{ELG Order}\\
#      \multicolumn{1}{c}{}& &  0&1&  2 &3\\ \cline{3-6}
#
#     \multirow[|l|]{4}{*}{\rotatebox[origin=c]{90}{LRG Order}}& \multicolumn{1}{c|}{0} && 2.39
#  ( 0.00654 ) & 11.1
#  ( 0.112 )&80.9
#  ( 4 )\\
#      & \multicolumn{1}{c|}{1} &16.6
#  ( 0.039 )&52.6
#  ( 0.39 )&374
#  ( 9.73 )&\multicolumn{1}{c}{}\\
#
#      &\multicolumn{1}{c|}{2} & 639
#  ( 4.21 )&2.56e+03
#  ( 71.2 )& \multicolumn{2}{c}{}\\
#      &\multicolumn{1}{c|}{3} &4.69e+04
#  ( 1.14e+03 )& \multicolumn{2}{c}{}\\
#
#     \end{tabular}
#
#     \end{table}

# %%
string1 = printMomentTableLaTeX(compelg_npcf,r'''$\bar{\xi}$: Ratio of Mock Catalogs to SV3, ELG-Centered''',lrg=False)
print(string1)
string1 = printMomentTableLaTeX(complrg_npcf,r'''$\bar{\xi}$: Ratio of Mock Catalogs to SV3, LRG-Centered''',lrg=True)
print(string1)
# Out:
#     \begin{table}
#     \caption{$\bar{\xi}$: Ratio of Mock Catalogs to SV3, ELG-Centered}
#     \begin{tabular}{ c  c  c  c c c}
#     \multicolumn{2}{c}{}&\multicolumn{4}{c}{LRG Order}\\
#      \multicolumn{1}{c}{}& &  0&1&  2 &3\\ \cline{3-6}
#
#     \multirow[|l|]{4}{*}{\rotatebox[origin=c]{90}{ELG Order}}& \multicolumn{1}{c|}{0} && 0.956
#  ( 0.0454 ) & 0.812
#  ( 0.0852 )&0.774
#  ( 0.159 )\\
#      & \multicolumn{1}{c|}{1} &1.11
#  ( 0.0318 )&1.19
#  ( 0.178 )&1.23
#  ( 0.392 )&\multicolumn{1}{c}{}\\
#
#      &\multicolumn{1}{c|}{2} & 0.919
#  ( 0.205 )&1.32
#  ( 0.565 )& \multicolumn{2}{c}{}\\
#      &\multicolumn{1}{c|}{3} &0.514
#  ( 0.502 )& \multicolumn{2}{c}{}\\
#
#     \end{tabular}
#
#     \end{table}
#
#     \begin{table}
#     \caption{$\bar{\xi}$: Ratio of Mock Catalogs to SV3, LRG-Centered}
#     \begin{tabular}{ c  c  c  c c c}
#     \multicolumn{2}{c}{}&\multicolumn{4}{c}{ELG Order}\\
#      \multicolumn{1}{c}{}& &  0&1&  2 &3\\ \cline{3-6}
#
#     \multirow[|l|]{4}{*}{\rotatebox[origin=c]{90}{LRG Order}}& \multicolumn{1}{c|}{0} && 0.916
#  ( 0.0443 ) & 0.869
#  ( 0.143 )&0.551
#  ( 0.223 )\\
#      & \multicolumn{1}{c|}{1} &0.996
#  ( 0.0338 )&0.816
#  ( 0.0841 )&1.07
#  ( 0.316 )&\multicolumn{1}{c}{}\\
#
#      &\multicolumn{1}{c|}{2} & 0.783
#  ( 0.0699 )&0.736
#  ( 0.118 )& \multicolumn{2}{c}{}\\
#      &\multicolumn{1}{c|}{3} &0.802
#  ( 0.122 )& \multicolumn{2}{c}{}\\
#
#     \end{tabular}
#
#     \end{table}
