# %%
from CountsinCylinders import *
from astropy.table import Table
from astropy.table import vstack
import fitsio

# %%
#set up auto-reload for development purposes

# %load_ext autoreload
# %autoreload 2

# %%
#general parameters
R_CiC = 1 #radius in Mpc
L_CiC = 40 #height of cylinder in Mpc
zlim = [0.75,1]
psilim = [0.2,1.5]

# %% [markdown]
# ## Compute CiC in SV3 ##

# %%
#loadholes
holetableselg = []
holetableslrg = []
for i in range(117):
    spelg = Table.read("datafiles/Holes_ELG_SV3_tile"+str(i)+"_holes.csv",format = "csv")
    splrg = Table.read("datafiles/Holes_LRG_SV3_tile"+str(i)+"_holes.csv",format = "csv")
    holetableselg.append(spelg)
    holetableslrg.append(splrg)
holetableelg = vstack(holetableselg)
holetablelrg = vstack(holetableslrg)
print(len(holetableelg),len(holetablelrg))
# Out:
# 4646361 4697603

# %%
#SV3 CiC, 26 July 2025
zlim = [0.8,1] #just for debugging 2pcf comparison
#FINAL for paper!!
#elgdownsamplefrac = 0.9627664301054767
#LSS SV3 catalogs, using ELGnotqso
file_elgS = '/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/ELG_HIPnotqso_S_clustering.dat.fits'#'/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/ELG_HIPnotqso_S_clustering.dat.fits'
file_elgN = '/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/ELG_HIPnotqso_N_clustering.dat.fits'#'/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/ELG_HIPnotqso_N_clustering.dat.fits'
file_lrgS = '/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/LRG_main_S_clustering.dat.fits'
file_lrgN = '/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/LRG_main_N_clustering.dat.fits'
columns = ['RA','DEC','Z']
columnnames = columns[:3]
sp1 = Table(fitsio.read(file_elgN, columns=columns))
sp2 = Table(fitsio.read(file_elgS, columns=columns))
sp3 = Table(fitsio.read(file_lrgN, columns=columns))
sp4 = Table(fitsio.read(file_lrgS, columns=columns))
spE = vstack([sp1,sp2])
spL = vstack([sp3,sp4])
spelg = spE[(spE["Z"] > zlim[0])&(spE["Z"] < zlim[1])]
splrg = spL[(spL["Z"] > zlim[0])&(spL["Z"] < zlim[1])]


primarymask = makePrimariesRosettesNoZBoundary
primaryargs = [*zlim,*psilim,R_CiC,L_CiC,'RA','DEC']

outfilename = "SV3_redshift08_R"+str(R_CiC)+"L40"

# %%
R_hole = 0.03*np.pi/180 #convert from degrees to radians
countsInCylindersHoleClean(spelg, splrg, holetableelg,holetablelrg,columnnames, R_CiC, L_CiC,R_hole, zlim, primarymask, primaryargs, outfilename)
#countsInCylinders(spelg, splrg, columnnames, R_CiC, L_CiC, zlim, primarymask, primaryargs, outfilename, secondarymask = makePrimariesRosettesNoZBoundary,secondaryargs=primaryargs)
# Out:
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 45647
# initial primary LRGs: 24184
# finished hole cleaning
# ELG primaries remaining: 40927
# LRG primaries remaining: 21271
# Pass rate, ELGs: 0.8965978048940785
# Pass rate, LRGs: 0.8795484617929209
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
# Pruning LRG auto-correlation
#    Galaxy 0
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
# Saved file datafiles/SV3_redshift08_R1L40_elg.csv
# Saved file datafiles/SV3_redshift08_R1L40_lrg.csv

# %%
#To check completeness in SV3
zlim = [0.75,1] #just for debugging 2pcf comparison

for i in range(25):
    mockdir = "/global/cfs/cdirs/desi/survey/catalogs/SV3/mocks/LSS_rea"
    mockdir += "{:03d}".format(i)
    mockdir += "/fuji/LSScats/1/"

    felgcomplete = mockdir + "ELG_full.dat.fits"
    felgincomplete = mockdir + "ELG_clustering.dat.fits"
    flrgcomplete = mockdir + "LRG_full.dat.fits"
    flrgincomplete = mockdir + "LRG_clustering.dat.fits"
    
    columns = ['RA','DEC','Z']
    elgcomplete = Table(fitsio.read(felgcomplete, columns=columns))
    elgincomplete = Table(fitsio.read(felgincomplete, columns=columns))
    lrgcomplete = Table(fitsio.read(flrgcomplete, columns=columns))
    lrgincomplete = Table(fitsio.read(flrgcomplete, columns=columns))
    
    elgcomplete
    primarymask = makePrimariesRosettes
    primaryargs = [*zlim,*psilim,R_CiC,L_CiC,'RA','DEC']
    
    outfile_complete = "SV3_mock_complete_"+str(i)
    outfile_incomplete = "SV3_mock_incomplete_"+str(i)
    R_hole = 0.03*np.pi/180 #convert from degrees to radians

    #complete
    countsInCylindersHoleClean(elgcomplete, lrgcomplete, holetableelg,holetablelrg,columnnames, R_CiC, L_CiC,R_hole, zlim, primarymask, primaryargs, outfile_complete)

    #incomplete
    countsInCylindersHoleClean(elgincomplete, lrgincomplete, holetableelg,holetablelrg,columnnames, R_CiC, L_CiC,R_hole, zlim, primarymask, primaryargs, outfile_incomplete)
# Out:
# '\nfile_elgS = \'/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/ELG_HIPnotqso_S_clustering.dat.fits\'#\'/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/ELG_HIPnotqso_S_clustering.dat.fits\'\nfile_elgN = \'/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/ELG_HIPnotqso_N_clustering.dat.fits\'#\'/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/ELG_HIPnotqso_N_clustering.dat.fits\'\nfile_lrgS = \'/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/LRG_main_S_clustering.dat.fits\'\nfile_lrgN = \'/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/LRG_main_N_clustering.dat.fits\'\ncolumns = [\'RA\',\'DEC\',\'Z\']\ncolumnnames = columns[:3]\nsp1 = Table(fitsio.read(file_elgN, columns=columns))\nsp2 = Table(fitsio.read(file_elgS, columns=columns))\nsp3 = Table(fitsio.read(file_lrgN, columns=columns))\nsp4 = Table(fitsio.read(file_lrgS, columns=columns))\nspE = vstack([sp1,sp2])\nspL = vstack([sp3,sp4])\nspelg = spE[(spE["Z"] > zlim[0])&(spE["Z"] < zlim[1])]\nsplrg = spL[(spL["Z"] > zlim[0])&(spL["Z"] < zlim[1])]\n\n\nprimarymask = makePrimariesRosettesNoZBoundary\nprimaryargs = [*zlim,*psilim,R_CiC,L_CiC,\'RA\',\'DEC\']\n\noutfilename = "SV3_redshift08_R"+str(R_CiC)+"L40"'

# %%
#rosettes['n_elim'] = [273,223,188,224,194,247,266,170,259,287,267,359,326,258,382,413,175,227,373262]

# %% [markdown]
# ### Counts in Cylinders in Abacus ##

# %%
#attempt to clean the forFA mocks
elgmocks = []
lrgmocks = []
columns = ['RA','DEC','RSDZ']
columnnames = columns[:4]
primarymask = makePrimariesZandAngular
ralim = [130,223]
declim  = [-5.25,3.75]
primaryargs = [*zlim,*ralim,*declim,R_CiC,L_CiC]
#zfailratio = 0.04649021864211737
print('check')

#loadholes
holetableselg = []
holetableslrg = []
for i in range(240):
    spelg = Table.read("datafiles/forFAelg_tile"+str(i)+"_holes.csv",format = "csv")
    splrg = Table.read("datafiles/forFAlrg_tile"+str(i)+"_holes.csv",format = "csv")
    holetableselg.append(spelg)
    holetableslrg.append(splrg)
holetableelg = vstack(holetableselg)
holetablelrg = vstack(holetableslrg)
print(len(holetableelg),len(holetablelrg))
# Out:
# check
# 2218580 2349008

# %%
R_hole = 0.03*np.pi/180 #convert from degrees to radians



#forFA Mocks, downsampled by redshift fraction but NOT using ebits
mocks = []
columns = ['RA','DEC','RSDZ','ZWARN','DESI_TARGET','MASKBITS'] #want to 
columnnames = columns[:3]
primarymask = makePrimariesZandAngular
ralim = [130,223]
declim  = [-5.25,3.75]
primaryargs = [*zlim,*ralim,*declim,R_CiC,L_CiC]

print(zlim)
for mocknumber in range(18):
    #for the moment, don't downsample by redshift success fraction
    lrgsuccess = 1 #0.90 #0.976*0.8812216895357733
    elgsuccess = 0.8062 #1 #0.811 #1 #0.97 #0.8360495775774505   #1 #0.86 #0.7171793765301621 #0.69/0.9627664301054767
    outfilename = "ffa_noebits_cleaned_"+str(mocknumber)+"_R"+str(R_CiC)+"L40"
    mockdir = mockdir = "/global/cfs/cdirs/desi//survey/catalogs/Y1/mocks/SecondGenMocks/AbacusSummit_v4_2/"
    #mockdir = "/global/cfs/cdirs/desi//survey/catalogs/Y1/mocks/SecondGenMocks/AbacusSummit_v4_2/"
    file = mockdir+ "forFA"+str(mocknumber)+".fits"
    #file_elg = mockdir + "mock"+str(mocknumber)+"/ELG_LOP_complete_clustering.dat.fits"
    #file_lrg = mockdir + "mock"+str(mocknumber)+"/LRG_complete_clustering.dat.fits"
    #get lrg mask from "matched input" lrg file
    sp = Table(fitsio.read(file,columns=columns))
    #sp = Table(fitsio.read(file_lrg,columns=columns))
    splrg = sp[(sp["DESI_TARGET"]&0x1==0x1)&(sp["RSDZ"] > zlim[0])&(sp["RSDZ"] < zlim[1])]
    #sp = Table(fitsio.read(file_elg,columns=columns))
    #file_elg = mockdir + "mock"+str(mocknumber)+"/ELG_LOP_complete_clustering.dat.fits"
    #spelg = Table(fitsio.read(file_elg,columns=['RA','DEC','Z']))
    spelg = sp[(sp["DESI_TARGET"]&0x20==0x20)&(sp["RSDZ"] > zlim[0])&(sp["RSDZ"] < zlim[1])]
    #spelg['RSDZ']=spelg['Z']
    elg_downsampled = spelg[[(np.random.rand() < elgsuccess) for i in range(len(spelg))]]
    lrg_downsampled = splrg[[(np.random.rand() < lrgsuccess) for i in range(len(splrg))]]
    countsInCylindersHoleClean(elg_downsampled,lrg_downsampled,holetablelrg,holetablelrg,
                      columnnames, R_CiC, L_CiC, R_hole, zlim, primarymask, primaryargs, outfilename)
# Out:
# [0.75, 1]
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 307260
# initial primary LRGs: 189459
# finished hole cleaning
# ELG primaries remaining: 271107
# LRG primaries remaining: 167450
# Pass rate, ELGs: 0.8823374340949034
# Pass rate, LRGs: 0.8838323858987961
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_0_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_0_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 307782
# initial primary LRGs: 188055
# finished hole cleaning
# ELG primaries remaining: 272078
# LRG primaries remaining: 166192
# Pass rate, ELGs: 0.8839958152198634
# Pass rate, LRGs: 0.8837414586158304
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_1_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_1_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 311849
# initial primary LRGs: 192577
# finished hole cleaning
# ELG primaries remaining: 275523
# LRG primaries remaining: 170156
# Pass rate, ELGs: 0.8835141366494682
# Pass rate, LRGs: 0.8835738431899968
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_2_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_2_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 307463
# initial primary LRGs: 191581
# finished hole cleaning
# ELG primaries remaining: 271451
# LRG primaries remaining: 169555
# Pass rate, ELGs: 0.882873711633595
# Pass rate, LRGs: 0.8850303526967706
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_3_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_3_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 314176
# initial primary LRGs: 196360
# finished hole cleaning
# ELG primaries remaining: 277833
# LRG primaries remaining: 173624
# Pass rate, ELGs: 0.8843227999592586
# Pass rate, LRGs: 0.8842126706050112
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_4_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_4_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 311664
# initial primary LRGs: 192856
# finished hole cleaning
# ELG primaries remaining: 275272
# LRG primaries remaining: 170438
# Pass rate, ELGs: 0.8832332255249242
# Pass rate, LRGs: 0.8837578296760277
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_5_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_5_R1L40_lrg.csv
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 308573
# initial primary LRGs: 191983
# finished hole cleaning
# ELG primaries remaining: 272729
# LRG primaries remaining: 169340
# Pass rate, ELGs: 0.8838394804470903
# Pass rate, LRGs: 0.8820572654870483
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_6_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_6_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 311766
# initial primary LRGs: 193625
# finished hole cleaning
# ELG primaries remaining: 275336
# LRG primaries remaining: 171119
# Pass rate, ELGs: 0.8831495416434121
# Pass rate, LRGs: 0.8837650096836669
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_7_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_7_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 310463
# initial primary LRGs: 192914
# finished hole cleaning
# ELG primaries remaining: 274419
# LRG primaries remaining: 170140
# Pass rate, ELGs: 0.8839024295970856
# Pass rate, LRGs: 0.8819473962491058
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_8_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_8_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 309221
# initial primary LRGs: 191200
# finished hole cleaning
# ELG primaries remaining: 273214
# LRG primaries remaining: 169334
# Pass rate, ELGs: 0.8835557740256968
# Pass rate, LRGs: 0.8856380753138076
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_9_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_9_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 309905
# initial primary LRGs: 194188
# finished hole cleaning
# ELG primaries remaining: 273885
# LRG primaries remaining: 171845
# Pass rate, ELGs: 0.8837708329972088
# Pass rate, LRGs: 0.8849413969967248
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_10_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_10_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 307510
# initial primary LRGs: 189513
# finished hole cleaning
# ELG primaries remaining: 271935
# LRG primaries remaining: 167440
# Pass rate, ELGs: 0.8843127052778771
# Pass rate, LRGs: 0.8835277790969485
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_11_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_11_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 310349
# initial primary LRGs: 191705
# finished hole cleaning
# ELG primaries remaining: 274146
# LRG primaries remaining: 169483
# Pass rate, ELGs: 0.8833474572175196
# Pass rate, LRGs: 0.8840823139719882
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_12_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_12_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 305666
# initial primary LRGs: 188513
# finished hole cleaning
# ELG primaries remaining: 269875
# LRG primaries remaining: 166544
# Pass rate, ELGs: 0.8829081415662847
# Pass rate, LRGs: 0.8834616180316477
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_13_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_13_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 311968
# initial primary LRGs: 194848
# finished hole cleaning
# ELG primaries remaining: 275635
# LRG primaries remaining: 172097
# Pass rate, ELGs: 0.8835361319109653
# Pass rate, LRGs: 0.8832371900147807
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_14_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_14_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 312371
# initial primary LRGs: 195002
# finished hole cleaning
# ELG primaries remaining: 275889
# LRG primaries remaining: 172447
# Pass rate, ELGs: 0.8832093888357114
# Pass rate, LRGs: 0.8843345196459523
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_15_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_15_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 308035
# initial primary LRGs: 190450
# finished hole cleaning
# ELG primaries remaining: 272136
# LRG primaries remaining: 167974
# Pass rate, ELGs: 0.8834580485983735
# Pass rate, LRGs: 0.8819847729062746
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_16_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_16_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 312895
# initial primary LRGs: 193956
# finished hole cleaning
# ELG primaries remaining: 276474
# LRG primaries remaining: 171407
# Pass rate, ELGs: 0.8835999296888732
# Pass rate, LRGs: 0.8837416733692177
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/forFA_noebits_cleaned_17_R1L40_elg.csv
# Saved file datafiles/forFA_noebits_cleaned_17_R1L40_lrg.csv

# %%
#compute CiC in mocks that have fiberassign

R_hole = 0.03*np.pi/180 #convert from degrees to radians



#forFA Mocks, downsampled by redshift fraction but NOT using ebits
mocks = []
columns = ['RA','DEC','Z','ZWARN','DESI_TARGET','MASKBITS'] #want to 
columnnames = columns[:3]
primarymask = makePrimariesZandAngular
ralim = [130,223]
declim  = [-5.25,3.75]
primaryargs = [*zlim,*ralim,*declim,R_CiC,L_CiC]

print(zlim)
for mocknumber in range(18):
    #for the moment, don't downsample by redshift success fraction
    lrgsuccess = 1 #0.90 #0.976*0.8812216895357733
    elgsuccess = 0.8062 #1 #0.811 #1 #0.97 #0.8360495775774505   #1 #0.86 #0.7171793765301621 #0.69/0.9627664301054767
    outfilename = "ffa_cleaned_"+str(mocknumber)+"_R"+str(R_CiC)+"L40"
    mockdir = "/global/cfs/cdirs/desi//survey/catalogs/Y1/mocks/SecondGenMocks/AbacusSummit_v4_2/"
    #mockdir = "/global/cfs/cdirs/desi//survey/catalogs/Y1/mocks/SecondGenMocks/AbacusSummit_v4_2/"
    #file = mockdir+ "mock"+str(mocknumber)+"/.fits"
    file_elg = mockdir + "mock"+str(mocknumber)+"/ELG_LOP_ffa_clustering.dat.fits"
    file_lrg = mockdir + "mock"+str(mocknumber)+"/LRG_ffa_clustering.dat.fits"
    #get lrg mask from "matched input" lrg file
    #sp = Table(fitsio.read(file,columns=columns))
    sp = Table(fitsio.read(file_lrg,columns=columns))
    splrg = sp[(sp["Z"] > zlim[0])&(sp["Z"] < zlim[1])]
    sp = Table(fitsio.read(file_elg,columns=columns))
    #file_elg = mockdir + "mock"+str(mocknumber)+"/ELG_LOP_complete_clustering.dat.fits"
    sp = Table(fitsio.read(file_elg,columns=['RA','DEC','Z']))
    spelg = sp[(sp["Z"] > zlim[0])&(sp["Z"] < zlim[1])]
    #spelg['RSDZ']=spelg['Z']
    elg_downsampled = spelg[[(np.random.rand() < elgsuccess) for i in range(len(spelg))]]
    lrg_downsampled = splrg[[(np.random.rand() < lrgsuccess) for i in range(len(splrg))]]
    countsInCylindersHoleClean(elg_downsampled,lrg_downsampled,holetablelrg,holetablelrg,
                      columnnames, R_CiC, L_CiC, R_hole, zlim, primarymask, primaryargs, outfilename)
# Out:
# [0.75, 1]
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 120475
# initial primary LRGs: 155582
# finished hole cleaning
# ELG primaries remaining: 108923
# LRG primaries remaining: 142564
# Pass rate, ELGs: 0.9041128864909732
# Pass rate, LRGs: 0.9163270815389956
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_0_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_0_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 119905
# initial primary LRGs: 154375
# finished hole cleaning
# ELG primaries remaining: 108341
# LRG primaries remaining: 141401
# Pass rate, ELGs: 0.9035569826112338
# Pass rate, LRGs: 0.9159578947368421
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_1_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_1_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 122290
# initial primary LRGs: 157978
# finished hole cleaning
# ELG primaries remaining: 110652
# LRG primaries remaining: 144670
# Pass rate, ELGs: 0.9048327745522937
# Pass rate, LRGs: 0.9157604223372875
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_2_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_2_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 119764
# initial primary LRGs: 157529
# finished hole cleaning
# ELG primaries remaining: 108025
# LRG primaries remaining: 144352
# Pass rate, ELGs: 0.9019822317223873
# Pass rate, LRGs: 0.9163519098070831
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_3_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_3_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 122758
# initial primary LRGs: 160959
# finished hole cleaning
# ELG primaries remaining: 110841
# LRG primaries remaining: 147465
# Pass rate, ELGs: 0.9029228237670864
# Pass rate, LRGs: 0.9161649861144764
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_4_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_4_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 121958
# initial primary LRGs: 158786
# finished hole cleaning
# ELG primaries remaining: 110284
# LRG primaries remaining: 145294
# Pass rate, ELGs: 0.9042785221141705
# Pass rate, LRGs: 0.9150302923431537
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_5_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_5_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 120842
# initial primary LRGs: 157868
# finished hole cleaning
# ELG primaries remaining: 109336
# LRG primaries remaining: 144318
# Pass rate, ELGs: 0.9047847602654706
# Pass rate, LRGs: 0.9141687992500064
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_6_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_6_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 122280
# initial primary LRGs: 158913
# finished hole cleaning
# ELG primaries remaining: 110479
# LRG primaries remaining: 145494
# Pass rate, ELGs: 0.9034919856068041
# Pass rate, LRGs: 0.9155575692359971
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_7_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_7_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_8_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_8_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 121060
# initial primary LRGs: 157413
# finished hole cleaning
# ELG primaries remaining: 109381
# LRG primaries remaining: 144408
# Pass rate, ELGs: 0.9035271766066413
# Pass rate, LRGs: 0.9173829353357092
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_9_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_9_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 121132
# initial primary LRGs: 159852
# finished hole cleaning
# ELG primaries remaining: 109630
# LRG primaries remaining: 146551
# Pass rate, ELGs: 0.9050457352309876
# Pass rate, LRGs: 0.9167917823987188
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_10_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_10_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 120603
# initial primary LRGs: 155986
# finished hole cleaning
# ELG primaries remaining: 109269
# LRG primaries remaining: 142677
# Pass rate, ELGs: 0.9060222382527798
# Pass rate, LRGs: 0.9146782403549036
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_11_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_11_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 121774
# initial primary LRGs: 157475
# finished hole cleaning
# ELG primaries remaining: 110019
# LRG primaries remaining: 144240
# Pass rate, ELGs: 0.9034687207449866
# Pass rate, LRGs: 0.9159549134783299
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_12_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_12_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 119605
# initial primary LRGs: 154637
# finished hole cleaning
# ELG primaries remaining: 108242
# LRG primaries remaining: 141555
# Pass rate, ELGs: 0.9049956105513983
# Pass rate, LRGs: 0.9154018766530649
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_13_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_13_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 121251
# initial primary LRGs: 160132
# finished hole cleaning
# ELG primaries remaining: 109622
# LRG primaries remaining: 146638
# Pass rate, ELGs: 0.9040915126473184
# Pass rate, LRGs: 0.9157320210826069
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_14_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_14_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 121923
# initial primary LRGs: 159922
# finished hole cleaning
# ELG primaries remaining: 110169
# LRG primaries remaining: 146580
# Pass rate, ELGs: 0.9035948918579759
# Pass rate, LRGs: 0.9165718287665237
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_15_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_15_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 120974
# initial primary LRGs: 156269
# finished hole cleaning
# ELG primaries remaining: 109421
# LRG primaries remaining: 142934
# Pass rate, ELGs: 0.9045001405260634
# Pass rate, LRGs: 0.9146663765686093
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_16_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_16_R1L40_lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating galaxies near holes
# initial ELGs: 121836
# initial primary LRGs: 158777
# finished hole cleaning
# ELG primaries remaining: 110067
# LRG primaries remaining: 145557
# Pass rate, ELGs: 0.9034029350930759
# Pass rate, LRGs: 0.9167385704478609
# Searching for neighbors in spheres
# Pruning galaxies from spheres
# Pruning ELG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG auto-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning ELG-LRG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Pruning LRG-ELG cross-correlation
#    Galaxy 0
#    Galaxy 100000
# Saved file datafiles/ffa_cleaned_17_R1L40_elg.csv
# Saved file datafiles/ffa_cleaned_17_R1L40_lrg.csv

# %% [markdown]
# # Counts around randoms #

# %% [markdown]
# ## Abacus ##

# %%
#general parameters
R_CiC = 1 #radius in Mpc
L_CiC = 40 #height of cylinder in Mpc
zlim = [0.75,1]
psilim = [0.2,1.5]

R_hole = 0.03*np.pi/180 #convert from degrees to radians
lrgsuccess = 1 #0.976*0.8812216895357733
elgsuccess = 0.8062 #0.8360495775774505 #0.7171793765301621 #0.69/0.9627664301054767
#forFA Mocks, downsampled by redshift fraction but NOT using ebits
mocks = []
columns = ['RA','DEC','RSDZ','ZWARN','DESI_TARGET','MASKBITS'] #want to 
colsrans = ['RA','DEC','Z']
columnnames = columns[:3]
primarymask = makePrimariesZandAngular
ralim = [130,223]
declim  = [-5.25,3.75]
primaryargs = [*zlim,*ralim,*declim,R_CiC,L_CiC]

#loadholes
holetableselg = []
holetableslrg = []
for i in range(240):
    spelg = Table.read("datafiles/forFAelg_tile"+str(i)+"_holes.csv",format = "csv")
    splrg = Table.read("datafiles/forFAlrg_tile"+str(i)+"_holes.csv",format = "csv")
    holetableselg.append(spelg)
    holetableslrg.append(splrg)
holetableelg = vstack(holetableselg)
holetablelrg = vstack(holetableslrg)
print(len(holetableelg),len(holetablelrg))



for mocknumber in range(18):
    outfilename = "forFA_countsaroundrandoms_"+str(mocknumber)+"R_"+str(R_CiC)
    mockdir = "/global/cfs/cdirs/desi//survey/catalogs/Y1/mocks/SecondGenMocks/AbacusSummit_v4_2/"
    file = mockdir+ "forFA"+str(mocknumber)+".fits"
    directory = "/pscratch/sd/c/crmiller/"
    elgtabs = []
    lrgtabs = []
    for i in range(1):
        elgranfile = mockdir+"/mock"+str(mocknumber)+"/ELG_LOP_complete_12_clustering.ran.fits"
        lrgranfile = mockdir+"/mock"+str(mocknumber)+"/LRG_complete_12_clustering.ran.fits"
        spranelg = Table(fitsio.read(elgranfile,columns=colsrans))
        spranlrg = Table(fitsio.read(lrgranfile,columns=colsrans))
        spranelg = spranelg[(spranelg["Z"] > zlim[0])&(spranelg["Z"] < zlim[1])&(spranelg['RA'] > ralim[0])& \
            (spranelg['RA'] < ralim[1])&(spranelg['DEC'] > declim[0])&(spranelg['DEC'] < declim[1])]
        spranlrg = spranlrg[(spranlrg["Z"] > zlim[0])&(spranlrg["Z"] < zlim[1])&(spranlrg['RA'] > ralim[0])& \
            (spranlrg['RA'] < ralim[1])&(spranlrg['DEC'] > declim[0])&(spranlrg['DEC'] < declim[1])]
        elgtabs.append(spranelg)
        lrgtabs.append(spranlrg)
    spranselg = vstack(elgtabs)
    spranselg['RSDZ']=spranselg['Z']
    spranslrg = vstack(lrgtabs)
    spranslrg['RSDZ']=spranslrg['Z']
    sp = Table(fitsio.read(file,columns=columns))
    #get lrg mask from "matched input" lrg file
    splrg = sp[(sp["DESI_TARGET"]&0x1==0x1)&(sp["ZWARN"]==0)&(sp["RSDZ"] > zlim[0])&(sp["RSDZ"] < zlim[1])]
    spelg = sp[(sp["DESI_TARGET"]&0x20==0x20)&(sp["ZWARN"]==0)&(sp["RSDZ"] > zlim[0])&(sp["RSDZ"] < zlim[1])]
    elg_downsampled = spelg[[(np.random.rand() < elgsuccess) for i in range(len(spelg))]]
    lrg_downsampled = splrg[[(np.random.rand() < lrgsuccess) for i in range(len(splrg))]]
    #we need separate ELG and LRG random catalogs
    #we count tracers of both types around each
    countsAroundRandomsHoleClean(spranslrg,elg_downsampled,lrg_downsampled,holetableelg,holetablelrg,
                      columnnames, R_CiC, L_CiC, R_hole, zlim, primarymask, primaryargs, outfilename+"lrg",directory=directory)
    countsAroundRandomsHoleClean(spranselg,elg_downsampled,lrg_downsampled,holetableelg,holetablelrg,
                      columnnames, R_CiC, L_CiC, R_hole, zlim, primarymask, primaryargs, outfilename+"elg_nodownsample",directory=directory)
# Out:
# 2218580 2349008
# Will try to save to location /pscratch/sd/c/crmiller/forFA_countsaroundrandoms_0R_1lrg.csv
# finding unit sphere coordinates of galaxies
# finding Cartesian coordinates of galaxies
# making cKDTrees
# eliminating randoms near holes
# initial randoms: 824554
# Searching for neighbors in spheres
# Pruning galaxies from spheres
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
#    Galaxy 300000
#    Galaxy 400000
#    Galaxy 500000
#    Galaxy 600000
#    Galaxy 700000
#    Galaxy 0
#    Galaxy 100000
#    Galaxy 200000
#    Galaxy 300000
#    Galaxy 400000
#    Galaxy 500000
#    Galaxy 600000
#    Galaxy 700000
# Will try to save to location /pscratch/sd/c/crmiller/forFA_countsaroundrandoms_0R_1elg_nodownsample.csv
# finding unit sphere coordinates of galaxies

# %% [markdown]
# ## SV3 Counts around Randoms ##

# %%
#loadholes
holetableselg = []
holetableslrg = []
for i in range(117):
    spelg = Table.read("datafiles/Holes_ELG_SV3_tile"+str(i)+"_holes.csv",format = "csv")
    splrg = Table.read("datafiles/Holes_LRG_SV3_tile"+str(i)+"_holes.csv",format = "csv")
    holetableselg.append(spelg)
    holetableslrg.append(splrg)
holetableelg = vstack(holetableselg)
holetablelrg = vstack(holetableslrg)
print(len(holetableelg),len(holetablelrg))


#Counts around randoms in SV3, 7/22/25
#FINAL for paper!!
zlim = [0.75, 1]
R_hole = 0.03*np.pi/180
#elgdownsamplefrac = 0.9627664301054767
#LSS SV3 catalogs, using ELGnotqso
file_elgS = '/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/ELG_HIPnotqso_S_clustering.dat.fits'
file_elgN = '/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/ELG_HIPnotqso_N_clustering.dat.fits'
file_lrgS = '/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/LRG_main_S_clustering.dat.fits'
file_lrgN = '/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/LRG_main_N_clustering.dat.fits'
columns = ['RA','DEC','Z']
columnnames = columns
sp1 = Table(fitsio.read(file_elgN, columns=columns))
sp2 = Table(fitsio.read(file_elgS, columns=columns))
sp3 = Table(fitsio.read(file_lrgN, columns=columns))
sp4 = Table(fitsio.read(file_lrgS, columns=columns))
spE = vstack([sp1,sp2])
spL = vstack([sp3,sp4])
spelg = spE[(spE["Z"] > zlim[0])&(spE["Z"] < zlim[1])]
splrg = spL[(spL["Z"] > zlim[0])&(spL["Z"] < zlim[1])]
primarymask = makePrimariesRosettes
primaryargs = [*zlim,*psilim,R_CiC,L_CiC,'RA','DEC']
outfilename = "SV3_countsaroundrandoms_"

ranelg = []
ranlrg = []
for i in range(18):
    file_elgS = '/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/ELG_S_'+str(i)+'_clustering.ran.fits'
    file_elgN = '/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/ELG_N_'+str(i)+'_clustering.ran.fits'
    file_lrgS = '/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/LRG_main_S_'+str(i)+'_clustering.ran.fits'
    file_lrgN = '/global/cfs/cdirs/desi/vac/edr/lss/v2.0/LSScats/clustering/LRG_main_N_'+str(i)+'_clustering.ran.fits'
    sp1 = Table(fitsio.read(file_elgN, columns=columns))
    sp2 = Table(fitsio.read(file_elgS, columns=columns))
    sp3 = Table(fitsio.read(file_lrgN, columns=columns))
    sp4 = Table(fitsio.read(file_lrgS, columns=columns))
    ranelg.append(sp1)
    ranelg.append(sp2)
    ranlrg.append(sp3)
    ranlrg.append(sp4)
spranselg = vstack(ranelg)
spranslrg = vstack(ranlrg)


countsAroundRandomsHoleClean(spranslrg,spelg,splrg,holetableelg,holetablelrg,
                      columnnames, R_CiC, L_CiC, R_hole, zlim, primarymask, primaryargs, outfilename+"lrg", directory = "/pscratch/sd/c/crmiller/")
countsAroundRandomsHoleClean(spranselg,spelg,splrg,holetableelg,holetablelrg,
                      columnnames, R_CiC, L_CiC, R_hole, zlim, primarymask, primaryargs, outfilename+"elg", directory = "/pscratch/sd/c/crmiller/")
