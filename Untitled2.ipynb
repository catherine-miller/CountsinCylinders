# %%
from astropy.table import Table, vstack
import numpy as np
import matplotlib.pyplot as plt
import fitsio

# %%
file = "/global/cfs/cdirs/desi/survey/catalogs/SV3/mocks/mockTargets_000_FirstGen_CutSky_alltracers_sv3bits.fits"
tab = Table(fitsio.read(file))

# %%
tab
# Out:
# <Table length=753892>
#     RA        DEC       TRUEZ       RSDZ    ... SV3_SCND_TARGET ZWARN TARGETID
#  float32    float32    float32    float32   ...      int64      int64  int64
# --------- ----------- ---------- ---------- ... --------------- ----- --------
# 270.96835   61.009598 0.41912854 0.42139953 ...               0     0        1
# 270.49673    61.51798  0.4272926 0.42717272 ...               0     0        2
#  270.9648    62.51473 0.42848983 0.42747468 ...               0     0        3
# 271.54034   62.468903 0.41969427 0.42124748 ...               0     0        4
# 272.14697   62.465836 0.42214623 0.42215815 ...               0     0        5
# 272.70825    63.38743  0.4277408 0.42764142 ...               0     0        6
# 273.52475   62.145554 0.42405325 0.42335227 ...               0     0        7
# 270.31665    61.23539  0.4265641  0.4261389 ...               0     0        8
#  271.1433   62.454132 0.42792028 0.42850617 ...               0     0        9
# ...

# %%
file = "/global/cfs/cdirs/desi/survey/catalogs/SV3/mocks/mockTargets_000_FirstGen_CutSky_alltracers_sv3bits.fits"
tabtar2 = Table(fitsio.read(file))

# %%
plt.scatter(tabtar['RA'],tabtar['DEC'])

# %%
print(len(tabtar),len(tabtar2))
# Out:
# 6237268 753892

# %%
file = "/global/cfs/cdirs/desi/survey/catalogs/SV3/mocks/mockRandom_100_FirstGen_CutSky_alltracers_sv3bits.fits"
targettab = Table(fitsio.read(file))

# %%
'''file = "/global/cfs/cdirs/desi/survey/catalogs/SV3/mocks/mockTargets_000_FirstGen_CutSky_alltracers_sv3bits.fits"
rantab = Table(fitsio.read(file))'''

# %%
plt.scatter(rantab['RA'],rantab['DEC'],s=0.3)
plt.scatter(targettab['RA'],targettab['DEC'],s=0.3)
plt.xlim(217.5,218)
plt.ylim(2.5,3)
# Out:
# (2.5, 3.0)

# %%
tab = tab[(tab['RSDZ'] > 1) & (tab['RSDZ'] < 1.1) ]
plt.scatter(tab['RA'],tab['DEC'],s=0.5,c=tab['RSDZ'])
plt.xlim(217,218)
plt.ylim(2,3)
# Out:
# (2.0, 3.0)

# %%
rantab
# Out:
# <Table length=753046>
#     RA       DEC      TRUEZ      RSDZ   ... NUMOBS_INIT ZWARN TARGETID
#  float32   float32   float32   float32  ...    int64    int64  int64
# --------- --------- --------- --------- ... ----------- ----- --------
#    271.81 63.618797 1.3065898 1.3065898 ...           0     0        1
# 270.20154    62.945 1.3001047 1.3001047 ...           0     0        2
# 273.09888 63.202522 1.3006709 1.3006709 ...           0     0        3
#  271.8667 63.916252 1.3098601 1.3098601 ...           0     0        4
#  270.7759  61.16217 1.3015683 1.3015683 ...           0     0        5
# 271.57593 62.229355 1.2991302 1.2991302 ...           0     0        6
# 270.52515  65.06733 1.2986588 1.2986588 ...           0     0        7
# 272.26788 63.781593 1.3056221 1.3056221 ...           0     0        8
# 273.40164  62.31121 1.3019363 1.3019363 ...           0     0        9
# 272.16394  61.67701 1.3135002 1.3135002 ...           0     0       10
# ...

# %%
tab
# Out:
# <Table length=753892>
#     RA        DEC       TRUEZ       RSDZ    ... SV3_SCND_TARGET ZWARN TARGETID
#  float32    float32    float32    float32   ...      int64      int64  int64
# --------- ----------- ---------- ---------- ... --------------- ----- --------
# 270.96835   61.009598 0.41912854 0.42139953 ...               0     0        1
# 270.49673    61.51798  0.4272926 0.42717272 ...               0     0        2
#  270.9648    62.51473 0.42848983 0.42747468 ...               0     0        3
# 271.54034   62.468903 0.41969427 0.42124748 ...               0     0        4
# 272.14697   62.465836 0.42214623 0.42215815 ...               0     0        5
# 272.70825    63.38743  0.4277408 0.42764142 ...               0     0        6
# 273.52475   62.145554 0.42405325 0.42335227 ...               0     0        7
# 270.31665    61.23539  0.4265641  0.4261389 ...               0     0        8
#  271.1433   62.454132 0.42792028 0.42850617 ...               0     0        9
# ...

# %%
file = "/global/cfs/cdirs/desi/survey/catalogs/SV3/mocks/LSS_rea000/fuji/LSScats/1/ELG_0_clustering.ran.fits"
rantab2 = Table(fitsio.read(file))

# %%
file = "/global/cfs/cdirs/desi/survey/catalogs/SV3/mocks/LSS_rea000/fuji/LSScats/1/ELG_comp_tile.fits"
elgcomp = Table(fitsio.read(file))

# %%
elgcomp
# Out:
# <Table length=51788>
#      TILES           COMP_TILE
#      str51            float64
# --------------- --------------------
#               1 0.038461538461538464
#     1-10-11-442                  1.0
#        1-10-442                  0.5
#            1-11                 0.25
#             1-2                  0.0
#          1-2-10                  0.0
# 1-2-3-10-11-442                  1.0
#      1-2-3-4-10                  1.0
#   1-2-3-4-10-11                  1.0
#  1-2-3-4-10-442                  1.0
#             ...                  ...
#       90-92-451   0.6666666666666666
#       90-92-452   0.6666666666666666
#              91               0.3125
#          91-451                0.375
#      91-451-452                  0.6
#          91-452  0.23255813953488372
#       91-92-452                  1.0
#              92  0.09803921568627451
#          92-451   0.3333333333333333
#          92-452  0.07142857142857142

# %%
plt.scatter(rantab2['RA'],rantab2['DEC'],s=0.5,c=rantab2['Z'])
plt.xlim(217,218)
plt.ylim(2,3)
# Out:
# (2.0, 3.0)

# %%
rantab = rantab[(rantab['RSDZ'] > 1) & (rantab['RSDZ'] < 1.1) ]
plt.scatter(rantab['RA'],rantab['DEC'],s=0.5,c=rantab['RSDZ'])
plt.xlim(217,218)
plt.ylim(2,3)
# Out:
# (2.0, 3.0)

# %%
rantab2 = rantab2[(rantab2['Z'] > 1) & (rantab2['Z'] < 1.1) ]
plt.scatter(rantab2['RA'],rantab2['DEC'],s=0.5,c=rantab2['Z'])
plt.xlim(217,218)
plt.ylim(2,3)
# Out:
# (2.0, 3.0)
